# %%
import pandas as pd
import pickle

# %%
pickle = pd.read_pickle('Project Code/pickle_DF_Fix.pkl')

# %%
pickle.columns
# Out:
# Index(['imdbID', 'year', 'genres', 'original air date', 'plot outline',
#        'runtimes', 'title', 'cast', 'country codes', 'director',
#        'language codes', 'production companies', 'rating', 'votes',
#        'certificates', 'box office', 'Simple_Data', 'Gross_Income'],
#       dtype='object')

# %%
pickle['plot outline']
# Out:
# 0       After the events of Captain America: Civil War...
# 1       As the Avengers and their allies have continue...
# 2       Jedi Master-in-hiding Luke Skywalker unwilling...
# 3       While the Parr family has accepted its collect...
# 4       All looks lost for the Rebellion against the E...
#                               ...
# 1796    A clever, roller-coaster thriller that centers...
# 1797    'Hannah' tells the story of Buddhist pioneer H...
# 1798    "Luis" tells the story of an 11-year-old boy w...
# 1799    Philippe Mars is a reasonable man in an unreas...
# 1800    Based on a true story that was claimed by writ...
# Name: plot outline, Length: 1801, dtype: object

# %%
pickle
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ...
