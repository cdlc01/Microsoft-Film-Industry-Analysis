# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ast
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline

# %%
df = pd.read_csv('Project Code/BOM_IMDb.csv')

# %% [markdown]
# ## Word Map From The Plot Outline

# %%
df_plot = df_plot.dropna()
giant_word = ' '.join([df_plot['plot outline'][i] for i in list(df_plot.index)])

wordcloud = WordCloud(width = 800, height = 400).generate(giant_word) 
plt.figure(figsize = (18, 18))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Which genres are the most profitable?

# %%
df_gross = df
df_gross = df_gross.dropna()
df_gross['box office'] = df_gross['box office'].apply(lambda x: ast.literal_eval(x))

df_gross['box office'][0]['Cumulative Worldwide Gross']
# Out:
# <ipython-input-130-ec9fc7ce2e00>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gross['box office'] = df_gross['box office'].apply(lambda x: ast.literal_eval(x))
# '$1,347,071,259'

# %%
#df_gross['Cumulative Worldwide Gross'] = [int(ast.literal_eval(df['box office'][i])['Cumulative Worldwide Gross'][1:].replace(',', '_')) for i in range(853)]
#df_gross['Cumulative Worldwide Gross'] =
